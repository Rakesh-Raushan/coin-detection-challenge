# %% [markdown]
# Try out our evaluator Module

# %%
import sys
from pathlib import Path

# Allow notebook to import from app/
sys.path.append(str(Path("..").resolve()))

from evaluation.evaluator import Evaluator

evaluator = Evaluator()
results = evaluator.run()

evaluator._save_report(results)

results
# Out:
# 2026-02-13 02:38:22,771 - INFO - Starting evaluation...
# 2026-02-13 02:38:30,730 - INFO - Evaluation complete.
# 2026-02-13 02:38:30,731 - INFO - {'mAP@0.5:0.95': 0.36881859972472386, 'mAP@0.5': 0.41963299443616564, 'count_accuracy': 0.39790575916230364}
# {'mAP@0.5:0.95': 0.36881859972472386,
#  'mAP@0.5': 0.41963299443616564,
#  'count_accuracy': 0.39790575916230364}
